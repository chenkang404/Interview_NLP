# %%
import pandas as pd

# %%
df = pd.ExcelFile("./test_v1.xlsx")

# %%
print(df.sheet_names)
print(len(df.sheet_names))
# Out:
# ['甲状腺超声', '肺部CT', '肾脏腹部超声', '肝脏腹部超声', '胆囊腹部超声', '胰腺腹部超声', '脾脏腹部超声', '子宫腹部超声', '乳腺超声', '膀胱泌尿系统超声']
# 10

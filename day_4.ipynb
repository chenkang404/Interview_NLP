# %%
class MinStack:
    def __init__(self):
        self.stack = []       # 主栈，存储所有元素
        self.min_stack = []   # 辅助栈，存储当前最小值

    def push(self, val: int) -> None:
        self.stack.append(val)
        # 辅助栈为空时直接压入，否则压入当前最小值与新值的较小者
        if not self.min_stack:
            self.min_stack.append(val)
        else:
            self.min_stack.append(min(val, self.min_stack[-1]))

    def pop(self) -> None:
        self.stack.pop()
        self.min_stack.pop()

    def top(self) -> int:
        return self.stack[-1]

    def getMin(self) -> int:
        return self.min_stack[-1]
    
class MinStack_v2:
    def __init__(self):
        self.stack = []
        self.min_stack = []
    def push(self,val:int) -> None:
        self.stack.append(val)
        if not self.min_stack or val <= self.min_stack[-1]:
            self.min_stack.append(val)
    def pop(self) -> None:
        if self.stack.pop() == self.min_stack[-1]:
            self.min_stack.pop()
    def top(self) -> int:
        return self.stack[-1]
    def minstack(self) -> int:
        return self.min_stack[-1]

# %%
list_ = [2,3,5]
print(list_)
list_.pop()
print(list_)
# Out:
# [2, 3, 5]
# [2, 3]

# %%
minStack = MinStack_v2()
minStack.push(-2)
minStack.push(0)
minStack.push(-3)

# %%
minStack.min_stack
# Out:
# [-2, -3]

# %%
# 测试辅助栈法
minStack = MinStack()
minStack.push(-2)
minStack.push(0)
minStack.push(-3)
print(minStack.getMin())  # 输出 -3
minStack.pop()
print(minStack.top())     # 输出 0
print(minStack.getMin())  # 输出 -2

# %%
strs = "acdb"
strs_sorted= sorted(strs)
print(strs)
print(strs_sorted)
# Out:
# acdb
# ['a', 'b', 'c', 'd']

# %%
list_ = ["2","1","4","3"]
list_.sort()
print(list_)
# Out:
# ['1', '2', '3', '4']

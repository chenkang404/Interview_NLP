# %% [markdown]
# - 神经网络
#     - bert
#     - crf
#     - lstm
#     - cnn
#         - dropout作用：过拟合的解决，过拟合是指模型在训练数据上表现很好，但在未见过的测试数据上表现较差。Dropout通过以下方式解决过拟合问题：
#             - 模型泛化能力增强：由于每次训练时随机丢弃神经元，网络的不同部分在不同的训练过程中都会被激活。这样，模型不能依赖某些特定的神经元，而是必须学会在不同的组合中表现良好。这种训练方式可以提高模型的泛化能力。
#             - 避免共适应性（Co-adaptation）：神经元之间的共适应性会导致模型过拟合，因为某些神经元可能会“协作”去记住训练数据的某些模式。通过随机丢弃神经元，Dropout破坏了这种共适应性，使每个神经元在做决策时更独立。
#             - 缩放处理：为了保证训练和测试阶段神经元输出的期望一致，在训练时对未被丢弃的神经元的输出进行缩放处理。具体做法是将未被丢弃的神经元的输出除以 。这样做的原因是，在训练时由于部分神经元被丢弃，整体的输出值会变小。通过除以 ，可以使得输出的期望与不使用 Dropout 时的期望相同，从而保证在测试阶段不进行随机丢弃操作时，模型的行为与训练阶段一致。
#         - pooling
#             - max_pooling
#             - mean_pooling
# - llm
#     - 模型&训练
#         - 缩放因子，调节点积注意力中的内积大小，防止得分过大或过小，从而防止梯度消失或爆炸问题。点积的值之所以会变得很大，主要是由于向量维度的增加。可以从数学和统计的角度来看点积的计算过程。点积的期望值和方差：期望值E[qk]=0,方差Var[qk]=dk,随着维度dk增加，点积的方差dk也会增大。这意味着点积值的绝对值会随着维度的增加而变得越来越大，点积的数值范围会变得非常大。
#         - 激活函数
#         - decoder-only流行的原因
#         - 注意力机制
#             - MQA,GQA,MHA,MLA
#         - deepspeed
#             - 数据并行
#             - 模型并行
#                 - 张量并行
#                 - 流水线并行
#         - lora
#             - 变体
#                 - Qlora
#                 -
#
#             - 参数
#                 - rank:秩;
#                 - target_modules，对哪些参数进行微调;
#                 - alpha 其实是个缩放参数，训练后权重 merge 时的比例为 alpha/r
#                 - dropout:
#     - 模型推理
#
#
#
#     - RAG
#         - RAG和微调怎么选择
#         - Agent介绍一下
#         - 向量召回
#             - embedding:bge-m3,文本嵌入模型，用于将查询和文档映射到相同的向量空间。其核心目标是让相似的文本在高维向量空间中靠近
#             - rerank: bge-m3-rerank,Rerank模型直接输出相关性分数,模型采用的是二分类模型，对query-pos/query-neg句子对进行分类，采用的是回归任务的方式，即为相关性得分，适合用于排序

# %% [markdown]
# - deepseek
#     - 主要创新
#         - 多头潜在注意力机制
#         - deepseekMoE
#         - 多token预测(MTP)

# %% [markdown]
# 长城汽车·HRBP
# 职位详情
# 语音算法 对话系统 自然语言 大模型算法
# Python
# 岗位职责:
# 1.负责对话机器人、智能客服相关的NLU算法研究和开发，包括但不限于自然语言的意图分析、实体抽取、对话状态管理、对话生成、知识问答等算法的研究工作;
# 2.深入分析用户的使用数据，设计并实验新的优化自言语言理解整体效果的方法;
# 3.探索业界最新的研究成果，结合实际业务，落地到产品。任职要求:
# 1.工作1年以上，具有自然语言处理、模式识别或者机器学习相关专业硕士以上学历;
# 2.有知识问答系统、语音对话系统等相关开发经验者优先;
# 3.有Word Embedding、RNN、transformer、BERT等算法相关工作经验者优先;
# 4.扎实的Java或者Python的编程能力。
# 不感兴趣 继续沟通

# %%
大模型AI系统架构工程师(J8... 
百度·高级招聘经理
职位详情
cuda 推理加速 大模型 算子开发 并行计算 
工作职责:
1.参与大模型AI系统的研发，研究面向生成式大模型的训练和推理加速技术
2.深度优化大模型推理服务中的关键技术，如推理引擎、动态batching、模型量化、服务请求调度、低资源推理、投机式推理等
3.参与大模型的产品落地，包括基于反馈和强化学习算法的调整等;
4.推动大模型的技术研发，包括算法创新、系统评测等
任职资格:
1.具有计算机科学、人工智能、软件工程或相关专业大学本科及以上学历学位
2.优秀的编程能力，精通Python/C++，熟悉 PyTorch框架
3.对常见开源推理引擎(vllm，sglang，triton etc)有深度掌握的优先
4.掌握常见的大模型优化方案，熟悉主流的推理和训

# %% [markdown]
# 北京博睿宏运
# < AI大模型研发工程师
#
# 职位详情
# 金融/医疗/法律行业 模型服务化经验
# [岗位职责]
# 1.大模型研发与优化
# 主导LLM (如GPT、LLaMA、PaLM等)的预训练、微调、对齐及推理优化，提升模型性能与效率。
# 设计创新算法解决模型幻觉、长文本理解等核心问题。
# 开发模型压缩，量化，蒸馏技术，降低部署成本。跟踪Transformer、MoE、Agent等前沿技术，应用前沿技术到大模型研发和落地。
# 2.技术落地与业务结合
# 推动大模型在搜索，对话系统等场景的应用，实现技术到产品的转化。
# 推动大模型在智能运维领域的应用，将大模型能力落地到公司产品。
# 开发Prompt工程、RAG、Fine-tuning工具链，提升团队研发效能。
#
# [岗位技能要求]
# 1.技术基础
# 精通Transformer、Attention机制、位置编码等核心原理，熟悉RLHF、DPO对齐策略。
# 熟练使用Hugging Face、LangChain、vLLM等生态工具，掌握LoRA、P-Tuning高效微调方法。
# 2.工程能力
#  熟悉CUDA/TRT加速，具备模型服务化经验。
# 精通Python，熟悉Linux环境下大模型的蒸馏和微调。
# 具备高质量语料清洗、合成数据生成、多语言数据处理经验。
# 3.工作经验
# 2年以上NLP/大模型领域经验，主导过大模型全流程预训练，微调，对齐及推理优化。
# 有从0到1构建行业大模型(金融/医疗/法律等)的成功案例者优先。
# 计算机科学/AI方向硕士以上学历，顶会论文(NeurIPS/ICML/ACL)或开源项目贡献者优先。

# %% [markdown]
# Agent研发工程师(非算法)
# 乐学互娱
# 职位详情
# 物联网经验 大数据算法 不接受居家办公
# 智能体技术 分布式经验 PostgreSQL
# SpringCloud 云计算经验 查看全部
# 岗位职责:
# 1.参与或负责大模型应用平台及Agent框架的研发，包括智能体流程编排、任务调度核心模块的设计与实现。
# 2.深入探索智能体(Agent)技术方向，优化Agent的架构设计，提升其记忆、决策、推理及多Agent协作能力。
# 3.基于主流工作流框架(如Dify、LangChain等)进行二次开发，构建高效、可扩展的Agent开发工具链。
# 4.开发支持低代码/零代码的Agent编排系统，降低复杂流程的开发门槛
# 5.持续优化系统性能，解决高并发、分布式环境下的稳定性与效率问题。
#
# 任职要求:
# 1.学历背景:计算机科学、人工智能、软件工程等相关专业本科及以上学历。
# 2.技术能力:
# 1)熟悉智能体(Agent)核心概念与技术栈，包括但不限于流程编排、记忆机制、任务分解、工具调用等。
# 2)具备主流Agent框架(如Dify、LangChain、
# AutoGPT)开发经验，熟悉其架构设计与扩展机制。3)精通Python，熟悉Java/Go等至少一门后端语言4)了解大模型技术原理(如Prompt工程、RAG)，有 LLM应用开发经验者优先。
# 5)了解前端相关知识(如typescript、js)
# 6)具备优秀的逻辑思维与问题拆解能力，对前沿技术敏感，能快速学习并推动技术创新。
# 3.工作年限3年以内
